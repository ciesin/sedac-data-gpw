# %%
import os 
import arcpy
import pandas as pd

# %%
input_csv_path = r"F:\gpwv5\dashboard\csvs\GPWv5 Base Dashboard ISO_table_240207.csv"

dashboard_shape_path = r'F:\gpwv5\dashboard\gpwv5_dashboard.gdb\GPWv5Dashboard'

# %%
update_fields = ['ISO',
                 'ISO_alpha3_Code',
                 'Global_Code',
                    'Global_Name',
                    'Region_Code',
                    'Region_Name',
                    'Sub_region_Code',
                    'Sub_region_Name',
                    'Intermediate_Region_Code',
                    'Intermediate_Region_Name',
                    'Country_or_Area',
                    'M49_Code__AKA_ISO_Numeric_',
                    'ISO_alpha2_Code',
                    'Continent_GPW',
                    'Least_Developed_Countries__LDC_',
                    'Land_Locked_Developing_Countries__LLDC_',
                    'Small_Island_Developing_States__SIDS_',
                    'CensusTableRowsPerCountry',
                    'Stage_s_',
                    'Status',
                    'LatestCensusYear',
                    'PreviousCensusYear',
                    'Collection_Type',
                    'Frequency',
                    'Variable_Ingested',
                    'Hightest_Admin_Level_Ingested',
                    'Shape_Length',
                    'Shape_Area',
                    'Download_Link']

# %%
update_df = pd.read_csv(input_csv_path)
update_df= update_df.set_index('ISO')

# %%
df_columns = list(update_df.columns)
df_columns
# Out:
# ['ISO-alpha3 Code',
#  'Global Code',
#  'Global Name',
#  'Region Code',
#  'Region Name',
#  'Sub-region Code',
#  'Sub-region Name',
#  'Intermediate Region Code',
#  'Intermediate Region Name',
#  'Country or Area',
#  'M49 Code (AKA ISO Numeric)',
#  'ISO-alpha2 Code',
#  'Continent GPW',
#  'Least Developed Countries (LDC)',
#  'Land Locked Developing Countries (LLDC)',
#  'Small Island Developing States (SIDS)',
#  'CensusTableRowsPerCountry',
#  'Stage(s)',
#  'Status',
#  'LatestCensusYear',
#  'PreviousCensusYear',
#  'Collection Type',
#  'Frequency',
#  'Variable Ingested ',
#  'Hightest Admin Level Ingested ',
#  'Download Link']

# %%
update_dict = update_df.to_dict(orient='index')

# %%
dict(list(update_dict.items())[:1])
# Out:
# {'AFG': {'ISO-alpha3 Code': 'AFG',
#   'Global Code': 1.0,
#   'Global Name': 'World',
#   'Region Code': 142.0,
#   'Region Name': 'Asia',
#   'Sub-region Code': 34.0,
#   'Sub-region Name': 'Southern Asia',
#   'Intermediate Region Code': nan,
#   'Intermediate Region Name': nan,
#   'Country or Area': 'Afghanistan',
#   'M49 Code (AKA ISO Numeric)': 4.0,
#   'ISO-alpha2 Code': 'AF',
#   'Continent GPW': 'Asia',
#   'Least Developed Countries (LDC)': True,
#   'Land Locked Developing Countries (LLDC)': True,
#   'Small Island Developing States (SIDS)': nan,
#   'CensusTableRowsPerCountry': 1.0,
#   'Stage(s)': 'Boundary Ingest & Matching',
#   'Status': 'In Progress',
#   'LatestCensusYear': 2020.0,
#   'PreviousCensusYear': nan,
#   'Collection Type': 'Estimate/Projection',
#   'Frequency': 'Inconsistent',
#   'Variable Ingested ': 'Total/Sex/Age',
#   'Hightest Admin Level Ingested ': 0.0,
#   'Download Link': nan}}

# %%
feature_fields_list = arcpy.ListFields(dashboard_shape_path)

# %%
field_alias_list=[]
for field in feature_fields_list:
    field_alias_list.append(field.name)
field_alias_list= field_alias_list[6:]
field_alias_list = ['ISO',
 'ISO_alpha3_Code',
 'Global_Code',
 'Global_Name',
 'Region_Code',
 'Region_Name',
 'Sub_region_Code',
 'Sub_region_Name',
 'Intermediate_Region_Code',
 'Intermediate_Region_Name',
 'Country_or_Area',
 'M49_Code__AKA_ISO_Numeric_',
 'ISO_alpha2_Code',
 'Continent_GPW',
 'Least_Developed_Countries__LDC_',
 'Land_Locked_Developing_Countries__LLDC_',
 'Small_Island_Developing_States__SIDS_',
 'CensusTableRowsPerCountry',
 'Stage_s_',
 'Status',
 'LatestCensusYear',
 'PreviousCensusYear',
 'Collection_Type',
 'Frequency',
 'Variable_Ingested',
 'Hightest_Admin_Level_Ingested',
 'Download_Link']
field_alias_list
# Out:
# ['ISO',
#  'ISO_alpha3_Code',
#  'Global_Code',
#  'Global_Name',
#  'Region_Code',
#  'Region_Name',
#  'Sub_region_Code',
#  'Sub_region_Name',
#  'Intermediate_Region_Code',
#  'Intermediate_Region_Name',
#  'Country_or_Area',
#  'M49_Code__AKA_ISO_Numeric_',
#  'ISO_alpha2_Code',
#  'Continent_GPW',
#  'Least_Developed_Countries__LDC_',
#  'Land_Locked_Developing_Countries__LLDC_',
#  'Small_Island_Developing_States__SIDS_',
#  'CensusTableRowsPerCountry',
#  'Stage_s_',
#  'Status',
#  'LatestCensusYear',
#  'PreviousCensusYear',
#  'Collection_Type',
#  'Frequency',
#  'Variable_Ingested',
#  'Hightest_Admin_Level_Ingested',
#  'Download_Link']

# %%
with arcpy.da.UpdateCursor(dashboard_shape_path, field_alias_list) as cursor:
    # For each row, evaluate the WELL_YIELD value (index position 
    # of 0), and update WELL_CLASS (index position of 1)
    for row in cursor:
        iso_val = row[0]#'ISO',
        if iso_val in update_dict:
            print(iso_val)
            #print(update_dict[iso_val]['Stage(s)'])
            row[1]  = update_dict[iso_val]['ISO-alpha3 Code']# 'ISO_alpha3_Code',
            row[2] = update_dict[iso_val]['Global Code']# 'Global_Code',
            row[3]= update_dict[iso_val]['Global Name']# 'Global_Name',
            row[4]= update_dict[iso_val]['Region Code']# 'Region_Code',
            row[5]= update_dict[iso_val]['Region Name']# 'Region_Name',
            row[6]= update_dict[iso_val]['Sub-region Code']# 'Sub_region_Code',
            row[7]= update_dict[iso_val]['Sub-region Name']# 'Sub_region_Name',
            row[8]= update_dict[iso_val]['Intermediate Region Code']# 'Intermediate_Region_Code',
            row[9]= update_dict[iso_val]['Intermediate Region Name']# 'Intermediate_Region_Name',
            row[10]= update_dict[iso_val]['Country or Area']# 'Country_or_Area',
            row[11]= update_dict[iso_val]['M49 Code (AKA ISO Numeric)']# 'M49_Code__AKA_ISO_Numeric_',
            row[12]= update_dict[iso_val]['ISO-alpha2 Code']# 'ISO_alpha2_Code',
            row[13]= update_dict[iso_val]['Continent GPW']# 'Continent_GPW',
            row[14]= update_dict[iso_val]['Least Developed Countries (LDC)']# 'Least_Developed_Countries__LDC_',
            row[15]= update_dict[iso_val]['Land Locked Developing Countries (LLDC)']# 'Land_Locked_Developing_Countries__LLDC_',
            row[16]= update_dict[iso_val]['Small Island Developing States (SIDS)']# 'Small_Island_Developing_States__SIDS_',
            row[17]= update_dict[iso_val]['CensusTableRowsPerCountry']# 'CensusTableRowsPerCountry',
            row[18]= update_dict[iso_val]['Stage(s)']# 'Stage_s_',
            row[19]= update_dict[iso_val]['Status']# 'Status',
            row[20]= update_dict[iso_val]['LatestCensusYear']# 'LatestCensusYear',
            row[21]= update_dict[iso_val]['PreviousCensusYear']# 'PreviousCensusYear',
            row[22]= update_dict[iso_val]['Collection Type']# 'Collection_Type',
            row[23]= update_dict[iso_val]['Frequency']# 'Frequency',
            row[24]= update_dict[iso_val]['Variable Ingested ']# 'Variable_Ingested',
            row[25]= update_dict[iso_val]['Hightest Admin Level Ingested ']# 'Hightest_Admin_Level_Ingested',
            row[26]= update_dict[iso_val]['Download Link']# 'Download_Link'
            cursor.updateRow(row)
# Out:
# ATA
# Not Started
# ABW
# Boundary Adjustment
# AFG
# Boundary Ingest & Matching
# AGO
# Not Started
# AIA
# Acquisition
# ALA
# Not Started
# ALB
# Not Started
# ANR
# Not Started
# ARE
# Not Started
# ARG
# Ingest
# ARM
# Not Started
# ASM
# Boundary Adjustment
# ATF
# Not Started
# ATG
# Not Started
# AUT
# Acquisition
# AZE
# Acquisition
# BDI
# Not Started
# BEL
# Not Started
# BEN
# Not Started
# BES
# Not Started
# BFA
# Growth Rates
# BGD
# Acquisition
# BGR
# Boundary Ingest & Matching
# BHR
# Boundary Adjustment
# BHS
# Acquisition
# BIH
# Acquisition
# BLM
# Boundary Ingest & Matching
# BLR
# Acquisition
# BLZ
# Not Started
# BMU
# Boundary Adjustment
# BOL
# Not Started
# BRA
# Growth Rates
# BRB
# Acquisition
# BRN
# Growth Rates
# BTN
# Boundary Adjustment
# BVT
# Not Started
# BWA
# Acquisition
# CAF
# Not Started
# CAN
# Ingest
# CHE
# Boundary Ingest & Matching
# CHL
# Growth Rates
# CHN
# Acquisition
# CIV
# Acquisition
# CMR
# Not Started
# COD
# Acquisition
# COG
# Not Started
# COK
# Boundary Adjustment
# COL
# Growth Rates
# COM
# Boundary Ingest & Matching
# CPV
# Boundary Adjustment
# CRI
# Not Started
# CUB
# Not Started
# CUW
# Not Started
# CYM
# Boundary Ingest & Matching
# CYP
# Acquisition
# CZE
# Acquisition
# DEU
# Not Started
# DJI
# Not Started
# DMA
# Acquisition
# DNK
# Boundary Ingest & Matching
# DOM
# Not Started
# DZA
# Acquisition
# ECU
# Not Started
# EGY
# Growth Rates
# ERI
# Not Started
# ESH
# Not Started
# ESP
# Boundary Ingest & Matching
# EST
# Boundary Ingest & Matching
# ETH
# Ingest
# FIN
# Acquisition
# FJI
# Acquisition
# FLK
# Acquisition
# FRA
# Boundary Ingest & Matching
# FRO
# Not Started
# FSM
# Not Started
# GAB
# Not Started
# GEO
# Not Started
# GGY
# Ingest
# GHA
# Growth Rates
# GIB
# Not Started
# GIN
# Not Started
# GLP
# Growth Rates
# GMB
# Not Started
# GNB
# Not Started
# GNQ
# Acquisition
# GRC
# Acquisition
# GRD
# Acquisition
# GRL
# Not Started
# GTM
# Growth Rates
# GUF
# Boundary Ingest & Matching
# GUM
# Boundary Ingest & Matching
# GUY
# Not Started
# HKG
# Acquisition
# HMD
# Not Started
# HND
# Not Started
# HRV
# Acquisition
# HTI
# Acquisition
# HUN
# Not Started
# IDN
# Acquisition
# IMN
# Growth Rates
# IND
# Not Started
# IOT
# Not Started
# IRL
# Ingest
# IRN
# Growth Rates
# IRQ
# Not Started
# ISL
# Growth Rates
# ISR
# Acquisition
# ITA
# Acquisition
# JAM
# Not Started
# JEY
# Acquisition
# JOR
# Boundary Ingest & Matching
# JPN
# Acquisition
# KAZ
# Not Started
# KEN
# Ingest
# KGZ
# Acquisition
# KHM
